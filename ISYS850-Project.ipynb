# %%
import pandas as pd
import numpy as np

hours = pd.read_csv("annual_hours.csv")
happiness = pd.read_csv("happiness_2015.csv")
alcohol = pd.read_csv("drinks_2015.csv")

# %% [markdown]
# ## Hours

# %%
hours.head()
# Out:
#       Entity Code  Year  Average annual working hours per worker
# 0  Argentina  ARG  1950                                2034.0000
# 1  Argentina  ARG  1951                                2037.8667
# 2  Argentina  ARG  1952                                2041.7408
# 3  Argentina  ARG  1953                                2045.6223
# 4  Argentina  ARG  1954                                2049.5112

# %%
country_hours2015 = hours.loc[hours['Year']==2015].groupby('Entity')['Average annual working hours per worker'].max()
country_hours2015.head()
# Out:
# Entity
# Argentina     1691.5363
# Australia     1747.0090
# Austria       1598.8944
# Bangladesh    2232.3542
# Belgium       1544.6100
# Name: Average annual working hours per worker, dtype: float64

# %%
country_hours2015 = pd.DataFrame(country_hours2015)
country_hours2015
# Out:
#                 Average annual working hours per worker
# Entity
# Argentina                                     1691.5363
# Australia                                     1747.0090
# Austria                                       1598.8944
# Bangladesh                                    2232.3542
# Belgium                                       1544.6100
# ...                                                 ...
# Turkey                                        1832.0000
# United Kingdom                                1669.0747
# United States                                 1765.1826
# Uruguay                                       1552.3470
# Vietnam                                       2169.5916
#
# [66 rows x 1 columns]

# %%
country_hours2015['country'] = country_hours2015.index
country_hours2015 = country_hours2015[['country', 'Average annual working hours per worker']]
country_hours2015
# Out:
#                        country  Average annual working hours per worker
# Entity
# Argentina            Argentina                                1691.5363
# Australia            Australia                                1747.0090
# Austria                Austria                                1598.8944
# Bangladesh          Bangladesh                                2232.3542
# Belgium                Belgium                                1544.6100
# ...                        ...                                      ...
# Turkey                  Turkey                                1832.0000
# United Kingdom  United Kingdom                                1669.0747
# United States    United States                                1765.1826
# Uruguay                Uruguay                                1552.3470
# Vietnam                Vietnam                                2169.5916
#
# [66 rows x 2 columns]

# %% [markdown]
# ## Happiness

# %%
happiness
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
happiness.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
bad_cols = ['Region','Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 
            'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']
happiness.drop(bad_cols, axis=1, inplace=True)
happiness.sort_values(by=['Country'], inplace=True)

# %%
happiness.reset_index(inplace=True)
del happiness['index']

# %%
happiness
# Out:
#          Country  Happiness Rank  Happiness Score
# 0    Afghanistan             153            3.575
# 1        Albania              95            4.959
# 2        Algeria              68            5.605
# 3         Angola             137            4.033
# 4      Argentina              30            6.574
# ..           ...             ...              ...
# 153    Venezuela              23            6.810
# 154      Vietnam              75            5.360
# 155        Yemen             136            4.077
# 156       Zambia              85            5.129
# 157     Zimbabwe             115            4.610
#
# [158 rows x 3 columns]

# %% [markdown]
# ## Alcohol

# %%
alcohol
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# ...

# %%
country_hours2015.columns = country_hours2015.columns.str.lower()
happiness.columns = happiness.columns.str.lower()
alcohol.columns = alcohol.columns.str.lower()

country_hours2015['country'] = country_hours2015['country'].str.lower()
happiness['country'] = happiness['country'].str.lower()
alcohol['country'] = alcohol['country'].str.lower()

# %%
country_hours2015.index = range(len(country_hours2015.index))
country_hours2015.head()
# Out:
#       country  average annual working hours per worker
# 0   argentina                                1691.5363
# 1   australia                                1747.0090
# 2     austria                                1598.8944
# 3  bangladesh                                2232.3542
# 4     belgium                                1544.6100

# %%
happiness.head()
# Out:
#        country  happiness rank  happiness score
# 0  afghanistan             153            3.575
# 1      albania              95            4.959
# 2      algeria              68            5.605
# 3       angola             137            4.033
# 4    argentina              30            6.574

# %%
alcohol.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  afghanistan              0                0              0
# 1      albania             89              132             54
# 2      algeria             25                0             14
# 3      andorra            245              138            312
# 4       angola            217               57             45
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %%
hours_happiness = country_hours2015.merge(happiness, left_on = 'country', right_on = 'country')
hours_happiness
# Out:
#            country  average annual working hours per worker  happiness rank  \
# 0        argentina                                1691.5363              30
# 1        australia                                1747.0090              10
# 2          austria                                1598.8944              13
# 3       bangladesh                                2232.3542             109
# 4          belgium                                1544.6100              19
# ..             ...                                      ...             ...
# 60          turkey                                1832.0000              76
# 61  united kingdom                                1669.0747              21
# 62   united states                                1765.1826              15
# 63         uruguay                                1552.3470              32
# 64         vietnam                                2169.5916              75
#
#     happiness score
# 0             6.574
# ...

# %%
final_df = hours_happiness.merge(alcohol, left_on = 'country', right_on = 'country')
final_df
# Out:
#            country  average annual working hours per worker  happiness rank  \
# 0        argentina                                1691.5363              30
# 1        australia                                1747.0090              10
# 2          austria                                1598.8944              13
# 3       bangladesh                                2232.3542             109
# 4          belgium                                1544.6100              19
# ..             ...                                      ...             ...
# 56        thailand                                2185.4456              34
# 57          turkey                                1832.0000              76
# 58  united kingdom                                1669.0747              21
# 59         uruguay                                1552.3470              32
# 60         vietnam                                2169.5916              75
#
# ...

# %%
final_df.to_csv('hours_happiness_alcohol.csv')
